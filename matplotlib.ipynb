# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# File c:\Users\M.Hafeez\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:263
#     258         if parse_version(module.__version__) < parse_version(minver):
#     259             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     260                               f"you have {module.__version__}")
# --> 263 _check_versions()
#     266 # The decorator ensures this always returns the same handler (and it is only
#     267 # attached once).
#     268 @functools.cache
#     269 def _ensure_handler():
#
# File c:\Users\M.Hafeez\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:257, in _check_versions()
# ...

# %%
pip install msvc-runtime
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 1.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/1.9 MB 1.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# File c:\Users\M.Hafeez\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:968
#     961     return config
#     964 # When constructing the global instances, we need to perform certain updates
#     965 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     966 # triggering resolution of _auto_backend_sentinel.
#     967 rcParamsDefault = _rc_params_in_file(
# --> 968     cbook._get_data_path("matplotlibrc"),
#     969     # Strip leading comment.
#     970     transform=lambda line: line[1:] if line.startswith("#") else line,
#     971     fail_on_error=True)
#     972 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
# ...
