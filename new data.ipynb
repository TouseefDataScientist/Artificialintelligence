# %% [markdown]
# #### Name: Hira Arif

# %% [markdown]
# #### Email : Hiraarif077@gmail.com

# %% [markdown]
# ### Pandas Practice

# %% [markdown]
# ### Install Library

# %%
# %pip install pandas
# Out:
# ...
#
# ...

# %%
# %pip install openpyxl
# Out:
# ...
#
# ...

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Create the Data Frame from Excel File

# %%
dataset2=pd.read_excel("New Excel File.xlsx")
print("DATAFRAME")
dataset2
# Out:
# DATAFRAME
#   School Tecaher                   Email      Address Qualification   \
# 0            Huma      Huma123@gmail.com   Rawalpindi             MS
# 1          Aliya      Aliya677@gmail.com       Lahore            Bsc
# 2            Sara     Sara698@gmmail.com       Jehlum             BS
# 3           Sana       Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor    Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
#
#    Experience Previous Salary  Demand Salary
# 0           2              25k            40k
# 1           4              20k            45k
# 2           2              22k            58k
# ...

# %% [markdown]
# ### Using Different Functions

# %% [markdown]
# ### 1. Info Function

# %%
dataset2.info
# Out:
# <bound method DataFrame.info of   School Tecaher                   Email      Address Qualification   \
# 0            Huma      Huma123@gmail.com   Rawalpindi             MS
# 1          Aliya      Aliya677@gmail.com       Lahore            Bsc
# 2            Sara     Sara698@gmmail.com       Jehlum             BS
# 3           Sana       Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor    Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
#
#    Experience Previous Salary  Demand Salary
# 0           2              25k            40k
# 1           4              20k            45k
# ...

# %% [markdown]
# ### 2. Describe Function

# %%
dataset2.describe
# Out:
# <bound method NDFrame.describe of   School Tecaher                   Email      Address Qualification   \
# 0            Huma      Huma123@gmail.com   Rawalpindi             MS
# 1          Aliya      Aliya677@gmail.com       Lahore            Bsc
# 2            Sara     Sara698@gmmail.com       Jehlum             BS
# 3           Sana       Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor    Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
#
#    Experience Previous Salary  Demand Salary
# 0           2              25k            40k
# 1           4              20k            45k
# ...

# %% [markdown]
# ### 3. Data type  Function

# %%
dataset2.dtypes
# Out:
# School Tecaher      object
# Email               object
# Address             object
# Qualification       object
# Experience           int64
# Previous Salary     object
# Demand Salary       object
# dtype: object

# %% [markdown]
# ### 4. Slicing Function

# %%
dataset2[2:6]
# Out:
#   School Tecaher                  Email      Address Qualification   \
# 2            Sara    Sara698@gmmail.com       Jehlum             BS
# 3           Sana      Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor   Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa     Hafsa895@gmail.com  Rawalpindi              MS
#
#    Experience Previous Salary  Demand Salary
# 2           2              22k            58k
# 3           3              20k            52k
# 4           1              22k            40k
# 5           1              20k            60k

# %% [markdown]
# ### 5. Sorting by Column Function

# %%
dataset2.sort_values(by = "Address")
# Out:
#   School Tecaher                   Email      Address Qualification   \
# 4        Mahnoor    Mahnoor741@gmail.com    Islamabad             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 2            Sara     Sara698@gmmail.com       Jehlum             BS
# 3           Sana       Sana023@gmail.com          KPK            Fsc
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 1          Aliya      Aliya677@gmail.com       Lahore            Bsc
# 0            Huma      Huma123@gmail.com   Rawalpindi             MS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
#
#    Experience Previous Salary  Demand Salary
# 4           1              22k            40k
# 8           5              18k            43k
# 2           2              22k            58k
# ...

# %% [markdown]
# ### 6. Sorting by Index Function

# %%
dataset2.sort_index(axis = 1, ascending = True)
# Out:
#        Address Demand Salary                   Email  Experience  \
# 0   Rawalpindi            40k      Huma123@gmail.com           2
# 1       Lahore            45k     Aliya677@gmail.com           4
# 2       Jehlum            58k     Sara698@gmmail.com           2
# 3          KPK            52k      Sana023@gmail.com           3
# 4    Islamabad            40k   Mahnoor741@gmail.com           1
# 5  Rawalpindi             60k     Hafsa895@gmail.com           1
# 6          Kpk            40k     Aatka112@gmail.com           0
# 7        Sindh            30k   Shahida013@gmail.com           4
# 8     Islamabd            43k  Summiya113@gmail.com            5
# 9   Rawalpindi            50k    Riffat568@gmail.com           2
#
#   Previous Salary  Qualification  School Tecaher
# 0              25k             MS            Huma
# 1              20k            Bsc          Aliya
# 2              22k             BS            Sara
# 3              20k            Fsc           Sana
# ...

# %% [markdown]
# ### 7. Head Function

# %%
dataset2.head()
# Out:
#   School Tecaher                  Email     Address Qualification   \
# 0            Huma     Huma123@gmail.com  Rawalpindi             MS
# 1          Aliya     Aliya677@gmail.com      Lahore            Bsc
# 2            Sara    Sara698@gmmail.com      Jehlum             BS
# 3           Sana      Sana023@gmail.com         KPK            Fsc
# 4        Mahnoor   Mahnoor741@gmail.com   Islamabad             BS
#
#    Experience Previous Salary  Demand Salary
# 0           2              25k            40k
# 1           4              20k            45k
# 2           2              22k            58k
# 3           3              20k            52k
# 4           1              22k            40k

# %%
dataset2.head(3)
# Out:
#   School Tecaher                Email     Address Qualification   Experience  \
# 0            Huma   Huma123@gmail.com  Rawalpindi             MS           2
# 1          Aliya   Aliya677@gmail.com      Lahore            Bsc           4
# 2            Sara  Sara698@gmmail.com      Jehlum             BS           2
#
#   Previous Salary  Demand Salary
# 0              25k            40k
# 1              20k            45k
# 2              22k            58k

# %% [markdown]
# ### 8. Tail Function

# %%
dataset2.tail()
# Out:
#   School Tecaher                   Email      Address Qualification   \
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
#
#    Experience Previous Salary  Demand Salary
# 5           1              20k            60k
# 6           0              21k            40k
# 7           4              20k            30k
# 8           5              18k            43k
# 9           2              13k            50k

# %%
dataset2.tail(8)
# Out:
#   School Tecaher                   Email      Address Qualification   \
# 2            Sara     Sara698@gmmail.com       Jehlum             BS
# 3           Sana       Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor    Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa      Hafsa895@gmail.com  Rawalpindi              MS
# 6           Aatka     Aatka112@gmail.com          Kpk          Mphil
# 7         Shahida   Shahida013@gmail.com        Sindh             BS
# 8        Summiya   Summiya113@gmail.com      Islamabd             BS
# 9         Riffat     Riffat568@gmail.com   Rawalpindi             BS
#
#    Experience Previous Salary  Demand Salary
# 2           2              22k            58k
# 3           3              20k            52k
# 4           1              22k            40k
# 5           1              20k            60k
# 6           0              21k            40k
# 7           4              20k            30k
# ...

# %% [markdown]
# ### 9. Shape Function

# %%
dataset2.shape
# Out:
# (10, 7)

# %% [markdown]
# ### 10. Index Function

# %%
dataset2.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ### 11. Column Function

# %%
dataset2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dataset2.columns
#
# NameError: name 'dataset2' is not defined

# %% [markdown]
# ### 12. Location Function

# %%
dataset2.loc[:, ["Email", "Address"]]
# Out:
#                    Email      Address
# 0      Huma123@gmail.com   Rawalpindi
# 1     Aliya677@gmail.com       Lahore
# 2     Sara698@gmmail.com       Jehlum
# 3      Sana023@gmail.com          KPK
# 4   Mahnoor741@gmail.com    Islamabad
# 5     Hafsa895@gmail.com  Rawalpindi
# 6     Aatka112@gmail.com          Kpk
# 7   Shahida013@gmail.com        Sindh
# 8  Summiya113@gmail.com      Islamabd
# 9    Riffat568@gmail.com   Rawalpindi

# %%
dataset2.iloc[5,1]
# Out:
# 'Hafsa895@gmail.com'

# %%
dataset2.loc[1:2]
# Out:
#   School Tecaher                Email Address Qualification   Experience  \
# 1          Aliya   Aliya677@gmail.com  Lahore            Bsc           4
# 2            Sara  Sara698@gmmail.com  Jehlum             BS           2
#
#   Previous Salary  Demand Salary
# 1              20k            45k
# 2              22k            58k

# %%
dataset2.loc["2":"5"]
# Out:
#   School Tecaher                  Email      Address Qualification   \
# 2            Sara    Sara698@gmmail.com       Jehlum             BS
# 3           Sana      Sana023@gmail.com          KPK            Fsc
# 4        Mahnoor   Mahnoor741@gmail.com    Islamabad             BS
# 5          Hafsa     Hafsa895@gmail.com  Rawalpindi              MS
#
#    Experience Previous Salary  Demand Salary
# 2           2              22k            58k
# 3           3              20k            52k
# 4           1              22k            40k
# 5           1              20k            60k

# %%
dataset2.loc[2]
# Out:
# School Tecaher                    Sara
# Email               Sara698@gmmail.com
# Address                         Jehlum
# Qualification                       BS
# Experience                           2
# Previous Salary                    22k
# Demand Salary                      58k
# Name: 2, dtype: object

# %%
dataset2.Email
# Out:
# 0        Huma123@gmail.com
# 1       Aliya677@gmail.com
# 2       Sara698@gmmail.com
# 3        Sana023@gmail.com
# 4     Mahnoor741@gmail.com
# 5       Hafsa895@gmail.com
# 6       Aatka112@gmail.com
# 7     Shahida013@gmail.com
# 8    Summiya113@gmail.com
# 9      Riffat568@gmail.com
# Name: Email, dtype: object

# %% [markdown]
# ### 13. Transpose Function

# %%
dataset2.T
# Out:
#                                   0                   1                   2  \
# School Tecaher                 Huma              Aliya                 Sara
# Email             Huma123@gmail.com  Aliya677@gmail.com  Sara698@gmmail.com
# Address                  Rawalpindi              Lahore              Jehlum
# Qualification                    MS                 Bsc                  BS
# Experience                        2                   4                   2
# Previous Salary                 25k                 20k                 22k
# Demand Salary                   40k                 45k                 58k
#
#                                   3                     4                   5  \
# School Tecaher                Sana               Mahnoor               Hafsa
# Email             Sana023@gmail.com  Mahnoor741@gmail.com  Hafsa895@gmail.com
# Address                         KPK             Islamabad         Rawalpindi
# ...
