# %%
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
r = pd.read_excel("rimsha.xlsx")
print("Dataframe:")
r
# Out:
# Dataframe:
#       dep1 salary  dep2 salary  dep3 salary  dep4 salary  \
# 0        0.005512     0.789080     0.427407     0.222159
# 1        0.446477     0.506438     0.909260     0.955899
# 2        0.347004     0.548873     0.698345     0.978282
# 3        0.016929     0.538627     0.873815     0.596474
# 4        0.613361     0.803753     0.826520     0.913430
# ..            ...          ...          ...          ...
# 194      0.241452     0.985877     0.006969     0.792813
# 195      0.156987     0.241452     0.821725     0.714748
# 196      0.617559     0.156987     0.108459     0.348013
# 197      0.617559     0.615019     0.963761     0.345787
# 198           NaN     0.617559     0.780440     0.553339
#
#      dep5 salary dep6 salary dep7 salary dep8 salary dep9 salaray dep10 salary  \
# 0                                             0.903225
# 1                                             0.172990
# 2                                             0.201601
# ...

# %%
# Sorting
r.sort_index(axis=1, ascending=False)
# Out:
#      dep5 salary dep6 salary dep7 salary dep8 salary dep9 salaray dep10 salary  \
# 0                                             0.903225
# 1                                             0.172990
# 2                                             0.201601
# 3                                             0.751647
# 4                                             0.421756
# ..                                                 ...
# 194                                           0.713843
# 195                                           0.910443
# 196                                           0.693969
# 197                                           0.870168
# 198                                           0.636224
#
#      dep4 salary  dep3 salary  dep2 salary  Unnamed: 9  Unnamed: 8  \
# 0       0.222159     0.427407     0.789080    0.491347    0.437525
# 1       0.955899     0.909260     0.506438    0.488332    0.437828
# 2       0.978282     0.698345     0.548873    0.005264    0.117695
# ...

# %%
r.sort_values(by="dep3 salary")
# Out:
#       dep1 salary  dep2 salary  dep3 salary  dep4 salary  \
# 63       0.856240     0.864190     0.000673     0.597693
# 123      0.987740     0.431192     0.005267     0.415279
# 194      0.241452     0.985877     0.006969     0.792813
# 25       0.578908     0.222842     0.009840     0.550377
# 157      0.364767     0.252150     0.016298     0.701693
# ..            ...          ...          ...          ...
# 104      0.582067     0.517047     0.977446     0.953451
# 80       0.617559     0.041010     0.978007     0.869722
# 171      0.156987     0.585218     0.979996     0.231727
# 107      0.109294     0.847967     0.991187     0.093667
# 12       0.471638     0.667075     0.997773     0.256486
#
#      dep5 salary dep6 salary dep7 salary dep8 salary dep9 salaray dep10 salary  \
# 63                                            0.589320
# 123                                           0.162019
# 194                                           0.713843
# ...

# %%
r.info()            #Datatype info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 11 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0    dep1 salary                                                               198 non-null    float64
#  1   dep2 salary                                                                199 non-null    float64
#  2   dep3 salary                                                                199 non-null    float64
#  3   dep4 salary                                                                199 non-null    float64
#  4   dep5 salary dep6 salary dep7 salary dep8 salary dep9 salaray dep10 salary  199 non-null    float64
#  5   Unnamed: 5                                                                 199 non-null    float64
# ...

# %%
r.describe()      #statistic summry
# Out:
#         dep1 salary  dep2 salary  dep3 salary  dep4 salary  \
# count    198.000000   199.000000   199.000000   199.000000
# mean       0.450461     0.473016     0.523486     0.478317
# std        0.311390     0.299922     0.297310     0.272452
# min        0.003504     0.001610     0.000673     0.003399
# 25%        0.156987     0.188543     0.272795     0.264169
# 50%        0.438835     0.483458     0.531820     0.457765
# 75%        0.701551     0.735109     0.803411     0.673977
# max        0.988759     0.988897     0.997773     0.999015
#
#        dep5 salary dep6 salary dep7 salary dep8 salary dep9 salaray dep10 salary  \
# count                                         199.000000
# mean                                            0.517095
# std                                             0.294153
# min                                             0.000907
# 25%                                             0.259939
# 50%                                             0.558050
# ...

# %%
r.T                       #transposing data
# Out:
#                                                          0         1    \
#  dep1 salary                                        0.005512  0.446477
# dep2 salary                                         0.789080  0.506438
# dep3 salary                                         0.427407  0.909260
# dep4 salary                                         0.222159  0.955899
# dep5 salary dep6 salary dep7 salary dep8 salary...  0.903225  0.172990
# Unnamed: 5                                          0.533935  0.432143
# Unnamed: 6                                          0.129077  0.740027
# Unnamed: 7                                          0.406448  0.357880
# Unnamed: 8                                          0.437525  0.437828
# Unnamed: 9                                          0.491347  0.488332
# Unnamed: 10                                         0.921924  0.793447
#
#                                                          2         3    \
# ...
