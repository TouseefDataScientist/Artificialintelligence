# %% [markdown]
# ### Name:   Ambreen
# ### E-Mail: Ambreenkhan57ak@gmail.com
# ### Topic : Pandas functions implementation

# %% [markdown]
# ***

# %% [markdown]
# #### importing pandas and numpy and installing excel library

# %%
import pandas as pd
import numpy as np
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Read Excel file

# %%
df=pd.read_excel("data.xlsx")
df
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # display data types

# %%
df.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3    float64
# Unnamed: 4    float64
# Unnamed: 5    float64
# Unnamed: 6    float64
# Unnamed: 7    float64
# English       float64
# Urdu          float64
# Maths         float64
# Physics       float64
# Chemistry     float64
# Bio           float64
# PSt           float64
# Islamiat      float64
# dtype: object

# %% [markdown]
# #  view the top rows of the frame

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# #  view the  bottom rows of the frame

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # Display the DataFrame.index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=199, step=1)

# %% [markdown]
# # Return a NumPy representation of the underlying data

# %%
df.to_numpy()
# Out:
# array([[0.11947429, 0.23908534, 0.01243992, ..., 0.30958534, 0.26087863,
#         0.66741091],
#        [0.43090536, 0.38368075, 0.0826132 , ..., 0.50033728, 0.6206524 ,
#         0.4733549 ],
#        [0.2429972 , 0.5708073 , 0.77833637, ..., 0.77423584, 0.70735494,
#         0.25229538],
#        ...,
#        [0.73580017, 0.62805303, 0.40636229, ..., 0.9855525 , 0.04055542,
#         0.89229307],
#        [0.53352082, 0.65358287, 0.49087563, ..., 0.13804325, 0.78956053,
#         0.7579162 ],
#        [0.36473521, 0.03373949, 0.26630086, ..., 0.12124406, 0.24518436,
#         0.91071303]])

# %% [markdown]
# #  shows a quick statistic summary of your data:

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # Transposing your data:

# %%
df.T
# Out:
#                  0         1         2         3         4         5    \
# Unnamed: 0  0.119474  0.430905  0.242997  0.501628  0.344307  0.964187
# Unnamed: 1  0.239085  0.383681  0.570807  0.034464  0.601175  0.677779
# Unnamed: 2  0.012440  0.082613  0.778336  0.395550  0.918672  0.433837
# Unnamed: 3  0.571416  0.209430  0.806507  0.523063  0.585692  0.772602
# Unnamed: 4  0.403083  0.358533  0.533121  0.225245  0.115941  0.706721
# Unnamed: 5  0.738606  0.770771  0.648477  0.361950  0.004124  0.938622
# Unnamed: 6  0.276011  0.924578  0.275912  0.982694  0.405912  0.782732
# Unnamed: 7  0.882746  0.855662  0.660557  0.596087  0.366132  0.657180
# English     0.371731  0.115478  0.585514  0.783518  0.411279  0.374422
# Urdu        0.982237  0.066545  0.758866  0.803192  0.550334  0.734718
# Maths       0.384592  0.581165  0.095574  0.957146  0.855713  0.555575
# Physics     0.320944  0.780201  0.782417  0.571894  0.065382  0.268494
# ...

# %% [markdown]
# # sorts by an axis:

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#          Urdu  Unnamed: 7  Unnamed: 6  Unnamed: 5  Unnamed: 4  Unnamed: 3  \
# 0    0.982237    0.882746    0.276011    0.738606    0.403083    0.571416
# 1    0.066545    0.855662    0.924578    0.770771    0.358533    0.209430
# 2    0.758866    0.660557    0.275912    0.648477    0.533121    0.806507
# 3    0.803192    0.596087    0.982694    0.361950    0.225245    0.523063
# 4    0.550334    0.366132    0.405912    0.004124    0.115941    0.585692
# ..        ...         ...         ...         ...         ...         ...
# 194  0.295945    0.359416    0.449423    0.533068    0.179101    0.941922
# 195  0.452468    0.476602    0.280604    0.912314    0.978755    0.117274
# 196  0.523941    0.601370    0.091743    0.097980    0.856782    0.270686
# 197  0.066748    0.227123    0.150761    0.692654    0.201744    0.993591
# 198  0.363029    0.042142    0.267519    0.472611    0.307739    0.854474
#
#      Unnamed: 2  Unnamed: 1  Unnamed: 0   Physics       PSt     Maths  \
# ...

# %% [markdown]
# # sorts by values:

# %%
df.sort_values(by="Physics")
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 160    0.358136    0.360902    0.008176    0.842074    0.008311    0.385117
# 121    0.540432    0.231598    0.009499    0.573772    0.666239    0.239909
# 46     0.261798    0.362582    0.892979    0.785321    0.651400    0.720331
# 169    0.179646    0.615969    0.788366    0.478412    0.679147    0.464329
# 11     0.831046    0.449718    0.521597    0.026773    0.678444    0.904666
# ..          ...         ...         ...         ...         ...         ...
# 159    0.511038    0.004959    0.119052    0.910325    0.491001    0.752953
# 188    0.443226    0.251859    0.678660    0.900662    0.390349    0.720140
# 24     0.784440    0.982410    0.785201    0.982938    0.685725    0.863051
# 63     0.887467    0.570041    0.199356    0.591056    0.913262    0.904515
# 25     0.563647    0.656402    0.173696    0.331683    0.121638    0.075575
#
# ...

# %% [markdown]
# # passing a single label selects a columns

# %%
df["English"]
# Out:
# 0      0.371731
# 1      0.115478
# 2      0.585514
# 3      0.783518
# 4      0.411279
#          ...
# 194    0.750122
# 195    0.016388
# 196    0.193138
# 197    0.885846
# 198    0.459191
# Name: English, Length: 199, dtype: float64

# %% [markdown]
# # passing a slice : selects matching rows:

# %%
df[3:7]
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 3    0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4    0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# 5    0.964187    0.677779    0.433837    0.772602    0.706721    0.938622
# 6    0.821662    0.150356    0.275888    0.902729    0.655242    0.695251
#
#    Unnamed: 6  Unnamed: 7   English      Urdu     Maths   Physics  Chemistry  \
# 3    0.982694    0.596087  0.783518  0.803192  0.957146  0.571894   0.107210
# 4    0.405912    0.366132  0.411279  0.550334  0.855713  0.065382   0.784871
# 5    0.782732    0.657180  0.374422  0.734718  0.555575  0.268494   0.853117
# 6    0.253221    0.532274  0.898136  0.168568  0.663497  0.286084   0.339564
#
#         Bio       PSt  Islamiat
# 3  0.362442  0.585707  0.055925
# 4  0.460713  0.326616  0.396151
# 5  0.510372  0.686902  0.107564
# 6  0.420927  0.498138  0.306522

# %% [markdown]
# # Selecting all rows (:) with a select column labels:

# %%
df.loc[:, ["English", "Urdu"]]
# Out:
#       English      Urdu
# 0    0.371731  0.982237
# 1    0.115478  0.066545
# 2    0.585514  0.758866
# 3    0.783518  0.803192
# 4    0.411279  0.550334
# ..        ...       ...
# 194  0.750122  0.295945
# 195  0.016388  0.452468
# 196  0.193138  0.523941
# 197  0.885846  0.066748
# 198  0.459191  0.363029
#
# [199 rows x 2 columns]

# %% [markdown]
# # For label slicing, both endpoints are included:

# %%
df.loc["0":"2", ["English", "Urdu"]]
# Out:
#      English      Urdu
# 0   0.371731  0.982237
# 1   0.115478  0.066545
# 2   0.585514  0.758866
# 3   0.783518  0.803192
# 4   0.411279  0.550334
# 5   0.374422  0.734718
# 6   0.898136  0.168568
# 7   0.046759  0.467686
# 8   0.775195  0.642916
# 9   0.748434  0.354455
# 10  0.801723  0.069191
# 11  0.464519  0.947333
# 12  0.088781  0.064190
# 13  0.457365  0.706675
# 14  0.164095  0.128379
# 15  0.375415  0.933771
# 16  0.963268  0.307038
# 17  0.819817  0.853415
# 18  0.966639  0.267908
# 19  0.487010  0.588435

# %% [markdown]
# # Select via the position of the passed integers:

# %%
df.iloc[3]
# Out:
# Unnamed: 0    0.501628
# Unnamed: 1    0.034464
# Unnamed: 2    0.395550
# Unnamed: 3    0.523063
# Unnamed: 4    0.225245
# Unnamed: 5    0.361950
# Unnamed: 6    0.982694
# Unnamed: 7    0.596087
# English       0.783518
# Urdu          0.803192
# Maths         0.957146
# Physics       0.571894
# Chemistry     0.107210
# Bio           0.362442
# PSt           0.585707
# Islamiat      0.055925
# Name: 3, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#    Unnamed: 0  Unnamed: 1
# 3    0.501628    0.034464
# 4    0.344307    0.601175

# %% [markdown]
# # For slicing rows explicitly:

# %%
df.iloc[1:3, :]
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 1    0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2    0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
#
#    Unnamed: 6  Unnamed: 7   English      Urdu     Maths   Physics  Chemistry  \
# 1    0.924578    0.855662  0.115478  0.066545  0.581165  0.780201   0.048451
# 2    0.275912    0.660557  0.585514  0.758866  0.095574  0.782417   0.366413
#
#         Bio       PSt  Islamiat
# 1  0.500337  0.620652  0.473355
# 2  0.774236  0.707355  0.252295

# %% [markdown]
# # For slicing columns explicitly:

# %%
df.iloc[:, 1:3]
# Out:
#      Unnamed: 1  Unnamed: 2
# 0      0.239085    0.012440
# 1      0.383681    0.082613
# 2      0.570807    0.778336
# 3      0.034464    0.395550
# 4      0.601175    0.918672
# ..          ...         ...
# 194    0.619686    0.732752
# 195    0.429428    0.230312
# 196    0.628053    0.406362
# 197    0.653583    0.490876
# 198    0.033739    0.266301
#
# [199 rows x 2 columns]

# %% [markdown]
# # For getting a value explicitly

# %%
df.iloc[1, 1]
# Out:
# np.float64(0.38368075357360454)

# %%
df.iat[1, 1]
# Out:
# np.float64(0.38368075357360454)

# %% [markdown]
# # Boolean Indexing

# %% [markdown]
# # Select rows where df.English is greater than 0.

# %%
df[df["English"] > 0]
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %%
df[df > 0]
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.239085    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # Setting values by position

# %%
df.iat[0, 1] = 0

# %% [markdown]
# # Setting by assigning with a NumPy array:

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # A where operation with setting:

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     -0.119474    0.000000   -0.012440   -0.571416   -0.403083   -0.738606
# 1     -0.430905   -0.383681   -0.082613   -0.209430   -0.358533   -0.770771
# 2     -0.242997   -0.570807   -0.778336   -0.806507   -0.533121   -0.648477
# 3     -0.501628   -0.034464   -0.395550   -0.523063   -0.225245   -0.361950
# 4     -0.344307   -0.601175   -0.918672   -0.585692   -0.115941   -0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194   -0.276460   -0.619686   -0.732752   -0.941922   -0.179101   -0.533068
# 195   -0.599194   -0.429428   -0.230312   -0.117274   -0.978755   -0.912314
# 196   -0.735800   -0.628053   -0.406362   -0.270686   -0.856782   -0.097980
# 197   -0.533521   -0.653583   -0.490876   -0.993591   -0.201744   -0.692654
# 198   -0.364735   -0.033739   -0.266301   -0.854474   -0.307739   -0.472611
#
# ...

# %% [markdown]
# # DataFrame.dropna() drops any rows that have missing data

# %%
df.dropna(how="any")
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # DataFrame.fillna() fills missing data:

# %%
df.fillna(value=5)
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # isna() gets the boolean mask where values are nan

# %%
pd.isna(df)
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         False       False       False       False       False       False
# 1         False       False       False       False       False       False
# 2         False       False       False       False       False       False
# 3         False       False       False       False       False       False
# 4         False       False       False       False       False       False
# ..          ...         ...         ...         ...         ...         ...
# 194       False       False       False       False       False       False
# 195       False       False       False       False       False       False
# 196       False       False       False       False       False       False
# 197       False       False       False       False       False       False
# 198       False       False       False       False       False       False
#
# ...

# %% [markdown]
# # Calculate the mean value for each column:

# %%
df.mean
# Out:
# <bound method DataFrame.mean of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # Calculate the mean value for each row:

# %%
df.mean(axis=1)
# Out:
# 0      0.669915
# 1      0.717786
# 2      0.814082
# 3      0.755748
# 4      0.717236
#          ...
# 194    0.831186
# 195    0.742896
# 196    0.750043
# 197    0.769622
# 198    0.643653
# Length: 199, dtype: float64

# %% [markdown]
# # DataFrame.agg() and DataFrame.transform() applies a user defined function that reduces or broadcasts its result respectively.

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# Unnamed: 0     2.712762
# Unnamed: 1     2.828743
# Unnamed: 2     2.964626
# Unnamed: 3     2.887867
# Unnamed: 4     2.922258
# Unnamed: 5     2.929552
# Unnamed: 6     2.704311
# Unnamed: 7     2.922288
# English        2.922474
# Urdu           2.641387
# Maths          2.666532
# Physics        2.875530
# Chemistry      2.728628
# Bio            2.815767
# PSt            2.776693
# Islamiat       2.823019
# D             28.000000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     12.090798    0.000000    1.258920   57.827299   40.792003   74.746911
# 1     43.607622   38.828492    8.360456   21.194312   36.283527   78.002013
# 2     24.591316   57.765699   78.767641   81.618483   53.951799   65.625912
# 3     50.764737    3.487799   40.029610   52.933960   22.794765   36.629317
# 4     34.843882   60.838942   92.969635   59.272019   11.733246    0.417330
# ..          ...         ...         ...         ...         ...         ...
# 194   27.977721   62.712267   74.154470   95.322471   18.124973   53.946466
# 195   60.638434   43.458086   23.307566   11.868088   99.049974   92.326176
# 196   74.462978   63.558966   41.123864   27.393455   86.706326    9.915559
# 197   53.992307   66.142587   49.676614  100.551359   20.416499   70.096613
# 198   36.911203    3.414437   26.949647   86.472760   31.143209   47.828259
#
# ...

# %%
df.median
# Out:
# <bound method DataFrame.median of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %%
df.mode
# Out:
# <bound method DataFrame.mode of      Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      0.119474    0.000000    0.012440    0.571416    0.403083    0.738606
# 1      0.430905    0.383681    0.082613    0.209430    0.358533    0.770771
# 2      0.242997    0.570807    0.778336    0.806507    0.533121    0.648477
# 3      0.501628    0.034464    0.395550    0.523063    0.225245    0.361950
# 4      0.344307    0.601175    0.918672    0.585692    0.115941    0.004124
# ..          ...         ...         ...         ...         ...         ...
# 194    0.276460    0.619686    0.732752    0.941922    0.179101    0.533068
# 195    0.599194    0.429428    0.230312    0.117274    0.978755    0.912314
# 196    0.735800    0.628053    0.406362    0.270686    0.856782    0.097980
# 197    0.533521    0.653583    0.490876    0.993591    0.201744    0.692654
# 198    0.364735    0.033739    0.266301    0.854474    0.307739    0.472611
#
# ...

# %% [markdown]
# # Concatenating pandas objects together row-wise with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -2.584341  1.647171  0.797016  0.644898
# 1 -1.676099 -1.312164 -0.779453  0.669483
# 2 -1.490160  0.512368 -0.479858  1.756942
# 3  0.358882  1.003274  1.043870 -1.133735
# 4  0.666016 -0.279252  1.146745  0.502149
# 5  0.546438  1.082643  1.280902 -0.612302
# 6 -1.372233 -0.638160 -1.254429 -0.177401
# 7  1.771069 -0.190007 -1.274773 -0.128874
# 8  0.350400 -0.554932 -0.383457 -0.342560
# 9  0.286392 -1.365083 -1.104687  0.060574
