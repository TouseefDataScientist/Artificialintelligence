# %% [markdown]
# ### Name: Neha Izhar
# #### Email: nehaizhar123@gmail.com

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. Importing Dataframe

# %%
t=pd.read_excel("employee.xlsx")
t
# Out:
#    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 2. Datatype Function

# %%
t.dtypes
# Out:
# Name of Employee    object
# Age                  int64
# Qulification        object
# Experience          object
# Phone No             int64
# E-mail              object
# CNIC No              int64
# Address             object
# Salary               int64
# dtype: object

# %% [markdown]
# ### 3. Access specific Column Function

# %%
t.Age
# Out:
# 0     36
# 1     25
# 2     45
# 3     32
# 4     22
# 5     41
# 6     26
# 7     33
# 8     27
# 9     42
# 10    36
# 11    28
# 12    39
# 13    44
# 14    32
# 15    25
# 16    36
# 17    45
# 18    30
# 19    24
# 20    23
# Name: Age, dtype: int64

# %% [markdown]
# ### 4. Bool Function

# %%
t.bool
# Out:
# <bound method NDFrame.bool of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 5. Absolute Function

# %%
t.abs
# Out:
# <bound method NDFrame.abs of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 6. Boxplot Function

# %%
t.boxplot
# Out:
# <bound method boxplot_frame of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 7. Add Function

# %%
t.add
# Out:
# <bound method DataFrame.add of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 8. Column Accesser Function

# %%
t.Salary
# Out:
# 0     45000
# 1     25000
# 2     60000
# 3     30000
# 4     20000
# 5     50000
# 6     33000
# 7     40000
# 8     28000
# 9     36000
# 10    45000
# 11    22000
# 12    33000
# 13    20000
# 14    31000
# 15    44000
# 16    55000
# 17    23000
# 18    34000
# 19    35000
# 20    26000
# Name: Salary, dtype: int64

# %% [markdown]
# ### 9. Add_Prefix Function

# %%
t.add_prefix("range_")
# Out:
#    range_Name of Employee  range_Age range_Qulification range_Experience  \
# 0                    Amna         36             Master          5 years
# 1                  Ayesha         25                 BS          2 years
# 2                   Komal         45                PHD         10 years
# 3                  Kainat         32                 BS          6 years
# 4                    Isma         22                 BS          0 years
# 5                  Sawera         41                 MS          8 years
# 6                   Zahra         26             Master          1 years
# 7             Noor Fatima         33                 MS          5 years
# 8                  Kanwal         27                 BS          2 years
# 9                 Shaista         42                PHD         12 years
# 10                  Saira         36             Master          4 years
# 11                Hoorain         28             Master        2.7 years
# ...

# %% [markdown]
# ### 10. Add_Suffix Function

# %%
t.add_suffix("_range")
# Out:
#    Name of Employee_range  Age_range Qulification_range Experience_range  \
# 0                    Amna         36             Master          5 years
# 1                  Ayesha         25                 BS          2 years
# 2                   Komal         45                PHD         10 years
# 3                  Kainat         32                 BS          6 years
# 4                    Isma         22                 BS          0 years
# 5                  Sawera         41                 MS          8 years
# 6                   Zahra         26             Master          1 years
# 7             Noor Fatima         33                 MS          5 years
# 8                  Kanwal         27                 BS          2 years
# 9                 Shaista         42                PHD         12 years
# 10                  Saira         36             Master          4 years
# 11                Hoorain         28             Master        2.7 years
# ...

# %% [markdown]
# ### 11. Clip Function

# %%
t.clip(22000,26)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 t.clip(22000,26)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:9098, in NDFrame.clip(self, lower, upper, axis, inplace, **kwargs)
#    9096 # fast-path for scalars
#    9097 if (lower is None or is_number(lower)) and (upper is None or is_number(upper)):
# -> 9098     return self._clip_with_scalar(lower, upper, inplace=inplace)
#    9100 result = self
#    9101 if lower is not None:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:8838, in NDFrame._clip_with_scalar(self, lower, upper, inplace)
#    8835 mask = self.isna()
#    8837 if lower is not None:
# -> 8838     cond = mask | (self >= lower)
#    8839     result = result.where(
#    8840         cond, lower, inplace=inplace
# ...

# %% [markdown]
# ### 12. Column Function

# %%
t.columns
# Out:
# Index(['Name of Employee', 'Age', 'Qulification', 'Experience', 'Phone No',
#        'E-mail', 'CNIC No', 'Address', 'Salary'],
#       dtype='object')

# %% [markdown]
# ### 13. Align Function

# %%
t.align
# Out:
# <bound method NDFrame.align of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 14. Copy Function

# %%
s=t.copy()
s
# Out:
#    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 15. All Function

# %%
t.all()
# Out:
# Name of Employee    True
# Age                 True
# Qulification        True
# Experience          True
# Phone No            True
# E-mail              True
# CNIC No             True
# Address             True
# Salary              True
# dtype: bool

# %% [markdown]
# ###  16. Count Function

# %%
t.count()
# Out:
# Name of Employee    21
# Age                 21
# Qulification        21
# Experience          21
# Phone No            21
# E-mail              21
# CNIC No             21
# Address             21
# Salary              21
# dtype: int64

# %% [markdown]
# ### 17. Any Function

# %%
t.any()
# Out:
# Name of Employee    True
# Age                 True
# Qulification        True
# Experience          True
# Phone No            True
# E-mail              True
# CNIC No             True
# Address             True
# Salary              True
# dtype: bool

# %% [markdown]
# ### 18. Combine Function

# %%
t.combine
# Out:
# <bound method DataFrame.combine of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 19. Apply Function

# %%
t.apply
# Out:
# <bound method DataFrame.apply of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 20. Describe Function

# %%
t.describe()
# Out:
#              Age      Phone No       CNIC No        Salary
# count  21.000000  2.100000e+01  2.100000e+01     21.000000
# mean   32.904762  7.149200e+07  1.431297e+08  35000.000000
# std     7.641366  1.228317e+08  2.728283e+08  11401.754251
# min    22.000000  2.354780e+05  2.589631e+06  20000.000000
# 25%    26.000000  3.654897e+06  1.369875e+07  26000.000000
# 50%    32.000000  1.236588e+07  3.698722e+07  33000.000000
# 75%    39.000000  7.778955e+07  8.521480e+07  44000.000000
# max    45.000000  3.698745e+08  9.666548e+08  60000.000000

# %% [markdown]
# ### 21. Applymap Function

# %%
t.applymap
# Out:
# <bound method DataFrame.applymap of    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# ...

# %% [markdown]
# ### 22. Diference Function

# %%
t.diff()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 t.diff()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10044, in DataFrame.diff(self, periods, axis)
#   10041     # With periods=0 this is equivalent to a diff with axis=0
#   10042     axis = 0
# > 10044 new_data = self._mgr.diff(n=periods)
#   10045 res_df = self._constructor_from_mgr(new_data, axes=new_data.axes)
#   10046 return res_df.__finalize__(self, "diff")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.diff(self, n)
#     417 def diff(self, n: int) -> Self:
#     418     # only reached with self.ndim == 2
# --> 419     return self.apply("diff", n=n)
#
# ...

# %% [markdown]
# ### 23. Duplicate Function

# %%
t.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %% [markdown]
# ### 24. Head Function

# %%
t.head()
# Out:
#   Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0             Amna   36       Master    5 years   12365879   abc@gmail.com
# 1           Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 2            Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 3           Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4             Isma   22           BS    0 years  365426855   vgh@gmail.com
#
#     CNIC No Address  Salary
# 0  23548972     abc   45000
# 1  69874236     efg   25000
# 2  69842369     hij   60000
# 3  55845522     klm   30000
# 4  98723654     nop   20000

# %% [markdown]
# ### 25. Tail Function

# %%
t.tail()
# Out:
#    Name of Employee  Age Qulification Experience   Phone No         E-mail  \
# 16           Nabiha   36           BS    6 years   98741222  djn@gmail.com
# 17           Neelam   45           BS   15 years  369874521  kaj@gmail.com
# 18            Hibba   30       Master  1.5 years     235478  nlm@gmail.com
# 19            Hania   24       Master    0 years  333222555  yui@gmail.com
# 20           Umaima   23           BS  0.5 years    4782415  mno@gmail.com
#
#       CNIC No Address  Salary
# 16    7852235     xyz   55000
# 17   36987222     abh   23000
# 18  789214666     opl   34000
# 19   25899963     mny   35000
# 20   14788547     kji   26000

# %% [markdown]
# ### 26. Index Function

# %%
t.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %% [markdown]
# ### 27. Transporting Function

# %%
t.T
# Out:
#                              0               1              2   \
# Name of Employee           Amna          Ayesha          Komal
# Age                          36              25             45
# Qulification             Master              BS            PHD
# Experience              5 years         2 years       10 years
# Phone No               12365879         3654897       12551225
# E-mail            abc@gmail.com  vhzg@gmail.com  nsj@gmail.com
# CNIC No                23548972        69874236       69842369
# Address                     abc             efg            hij
# Salary                    45000           25000          60000
#
#                               3              4              5              6   \
# Name of Employee          Kainat           Isma         Sawera          Zahra
# Age                           32             22             41             26
# Qulification                  BS             BS             MS         Master
# ...

# %% [markdown]
# ### 28. Sort By Index Function

# %%
t.sort_index(axis=1,ascending=False)
# Out:
#     Salary Qulification   Phone No Name of Employee Experience  \
# 0    45000       Master   12365879             Amna    5 years
# 1    25000           BS    3654897           Ayesha    2 years
# 2    60000          PHD   12551225            Komal   10 years
# 3    30000           BS   36589712           Kainat    6 years
# 4    20000           BS  365426855             Isma    0 years
# 5    50000           MS    9842568           Sawera    8 years
# 6    33000       Master     514789            Zahra    1 years
# 7    40000           MS    3654897      Noor Fatima    5 years
# 8    28000           BS    7456695           Kanwal    2 years
# 9    36000          PHD    3654789          Shaista   12 years
# 10   45000       Master   87453216            Saira    4 years
# 11   22000       Master     254987          Hoorain  2.7 years
# 12   33000           BS    4569873           Nabila    7 years
# 13   20000          PHD   32147895            Nazia   11 years
# ...

# %% [markdown]
# ### 29. Sort By Value Function

# %%
t.sort_values(by="Qulification")
# Out:
#    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 20           Umaima   23           BS  0.5 years    4782415   mno@gmail.com
# 1            Ayesha   25           BS    2 years    3654897  vhzg@gmail.com
# 3            Kainat   32           BS    6 years   36589712  mjhg@gmail.com
# 4              Isma   22           BS    0 years  365426855   vgh@gmail.com
# 17           Neelam   45           BS   15 years  369874521   kaj@gmail.com
# 8            Kanwal   27           BS    2 years    7456695   lsk@gmail.com
# 16           Nabiha   36           BS    6 years   98741222   djn@gmail.com
# 15            Asifa   25           BS    3 years   36547888   lak@gmail.com
# 12           Nabila   39           BS    7 years    4569873  qwer@gamil.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# ...

# %% [markdown]
# ### 30. Getitem Function

# %%
t["Phone No"]
# Out:
# 0      12365879
# 1       3654897
# 2      12551225
# 3      36589712
# 4     365426855
# 5       9842568
# 6        514789
# 7       3654897
# 8       7456695
# 9       3654789
# 10     87453216
# 11       254987
# 12      4569873
# 13     32147895
# 14     77789546
# 15     36547888
# 16     98741222
# 17    369874521
# 18       235478
# 19    333222555
# 20      4782415
# Name: Phone No, dtype: int64

# %% [markdown]
# ### 31. Slicing Function

# %%
t[4:9]
# Out:
#   Name of Employee  Age Qulification Experience   Phone No         E-mail  \
# 4             Isma   22           BS    0 years  365426855  vgh@gmail.com
# 5           Sawera   41           MS    8 years    9842568  ksj@gmail.com
# 6            Zahra   26       Master    1 years     514789  lsk@gmail.com
# 7      Noor Fatima   33           MS    5 years    3654897  mns@gamil.com
# 8           Kanwal   27           BS    2 years    7456695  lsk@gmail.com
#
#     CNIC No Address  Salary
# 4  98723654     nop   20000
# 5  87456321     qrs   50000
# 6  35478921     tuv   33000
# 7   3654789     wxy   40000
# 8   9874563     zab   28000

# %% [markdown]
# ### 32. Loc Function

# %%
t.loc['Isma']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Isma'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 t.loc['Isma']
#
# ...

# %% [markdown]
# ### 33. LOc Function By Slicing

# %%
t.loc[:, ["Age", "E-mail"]]
# Out:
#     Age          E-mail
# 0    36   abc@gmail.com
# 1    25  vhzg@gmail.com
# 2    45   nsj@gmail.com
# 3    32  mjhg@gmail.com
# 4    22   vgh@gmail.com
# 5    41   ksj@gmail.com
# 6    26   lsk@gmail.com
# 7    33   mns@gamil.com
# 8    27   lsk@gmail.com
# 9    42   ksk@gmail.com
# 10   36   oia@gmail.com
# 11   28  bhsh@gmail.com
# 12   39  qwer@gamil.com
# 13   44  fisa@gmail.com
# 14   32   mjd@gmail.com
# 15   25   lak@gmail.com
# 16   36   djn@gmail.com
# 17   45   kaj@gmail.com
# 18   30   nlm@gmail.com
# 19   24   yui@gmail.com
# 20   23   mno@gmail.com

# %% [markdown]
# ### 34. Loc Function by index

# %%
t.loc[8]
# Out:
# Name of Employee           Kanwal
# Age                            27
# Qulification                   BS
# Experience                2 years
# Phone No                  7456695
# E-mail              lsk@gmail.com
# CNIC No                   9874563
# Address                       zab
# Salary                      28000
# Name: 8, dtype: object

# %% [markdown]
# ### 35. Iloc function by slicing

# %%
t.iloc[2:8,4:6]
# Out:
#     Phone No          E-mail
# 2   12551225   nsj@gmail.com
# 3   36589712  mjhg@gmail.com
# 4  365426855   vgh@gmail.com
# 5    9842568   ksj@gmail.com
# 6     514789   lsk@gmail.com
# 7    3654897   mns@gamil.com

# %% [markdown]
# ### 36. Boolean Greater Than Function

# %%
t[t["Salary"]>30000]
# Out:
#    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 5            Sawera   41           MS    8 years    9842568   ksj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 7       Noor Fatima   33           MS    5 years    3654897   mns@gamil.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# 12           Nabila   39           BS    7 years    4569873  qwer@gamil.com
# 14           Aneeqa   32       Master    1 years   77789546   mjd@gmail.com
# 15            Asifa   25           BS    3 years   36547888   lak@gmail.com
# 16           Nabiha   36           BS    6 years   98741222   djn@gmail.com
# ...

# %% [markdown]
# ### 37. Isin Function

# %%
t[t["Qulification"].isin(["Master","PHD"])]
# Out:
#    Name of Employee  Age Qulification Experience   Phone No          E-mail  \
# 0              Amna   36       Master    5 years   12365879   abc@gmail.com
# 2             Komal   45          PHD   10 years   12551225   nsj@gmail.com
# 6             Zahra   26       Master    1 years     514789   lsk@gmail.com
# 9           Shaista   42          PHD   12 years    3654789   ksk@gmail.com
# 10            Saira   36       Master    4 years   87453216   oia@gmail.com
# 11          Hoorain   28       Master  2.7 years     254987  bhsh@gmail.com
# 13            Nazia   44          PHD   11 years   32147895  fisa@gmail.com
# 14           Aneeqa   32       Master    1 years   77789546   mjd@gmail.com
# 18            Hibba   30       Master  1.5 years     235478   nlm@gmail.com
# 19            Hania   24       Master    0 years  333222555   yui@gmail.com
#
#       CNIC No Address  Salary
# 0    23548972     abc   45000
# 2    69842369     hij   60000
# 6    35478921     tuv   33000
# ...

# %% [markdown]
# ### 38. Setting value by label

# %%
t.at["Age"[0], "Age"] = 0
t
# Out:
#    Name of Employee   Age Qulification Experience     Phone No  \
# 0              Amna  36.0       Master    5 years   12365879.0
# 1            Ayesha  25.0           BS    2 years    3654897.0
# 2             Komal  45.0          PHD   10 years   12551225.0
# 3            Kainat  32.0           BS    6 years   36589712.0
# 4              Isma  22.0           BS    0 years  365426855.0
# 5            Sawera  41.0           MS    8 years    9842568.0
# 6             Zahra  26.0       Master    1 years     514789.0
# 7       Noor Fatima  33.0           MS    5 years    3654897.0
# 8            Kanwal  27.0           BS    2 years    7456695.0
# 9           Shaista  42.0          PHD   12 years    3654789.0
# 10            Saira  36.0       Master    4 years   87453216.0
# 11          Hoorain  28.0       Master  2.7 years     254987.0
# 12           Nabila  39.0           BS    7 years    4569873.0
# 13            Nazia  44.0          PHD   11 years   32147895.0
# ...

# %% [markdown]
# ### 39. Setting value by position

# %%
t.iat[11,4]
# Out:
# np.float64(0.0)

# %% [markdown]
# ### 40. Reindex Function

# %%
t = t.reindex(index="Hania"[0:4], columns=list(t.columns) + ["Elgibility"])
t.loc["Hania"[0] : "Hania"[1], "Eligibility"] = 1

t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 t = t.reindex(index="Hania"[0:4], columns=list(t.columns) + ["Elgibility"])
#       2 t.loc["Hania"[0] : "Hania"[1], "Eligibility"] = 1
#       4 t
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5378, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5359 @doc(
#    5360     NDFrame.reindex,
#    5361     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5376     tolerance=None,
#    5377 ) -> DataFrame:
# -> 5378     return super().reindex(
#    5379         labels=labels,
#    5380         index=index,
#    5381         columns=columns,
#    5382         axis=axis,
#    5383         method=method,
#    5384         copy=copy,
#    5385         level=level,
# ...

# %% [markdown]
# ### 41. Dropna Function

# %%
t.dropna(how="any")
# Out:
#    Name of Employee   Age Qulification Experience     Phone No  \
# 0              Amna  36.0       Master    5 years   12365879.0
# 1            Ayesha  25.0           BS    2 years    3654897.0
# 2             Komal  45.0          PHD   10 years   12551225.0
# 3            Kainat  32.0           BS    6 years   36589712.0
# 4              Isma  22.0           BS    0 years  365426855.0
# 5            Sawera  41.0           MS    8 years    9842568.0
# 6             Zahra  26.0       Master    1 years     514789.0
# 7       Noor Fatima  33.0           MS    5 years    3654897.0
# 8            Kanwal  27.0           BS    2 years    7456695.0
# 9           Shaista  42.0          PHD   12 years    3654789.0
# 10            Saira  36.0       Master    4 years   87453216.0
# 11          Hoorain  28.0       Master  2.7 years          0.0
# 12           Nabila  39.0           BS    7 years    4569873.0
# 13            Nazia  44.0          PHD   11 years   32147895.0
# ...

# %% [markdown]
# ### 42. Fillna Function

# %%
t.fillna(value=10)
# Out:
#    Name of Employee   Age Qulification Experience     Phone No  \
# 0              Amna  36.0       Master    5 years   12365879.0
# 1            Ayesha  25.0           BS    2 years    3654897.0
# 2             Komal  45.0          PHD   10 years   12551225.0
# 3            Kainat  32.0           BS    6 years   36589712.0
# 4              Isma  22.0           BS    0 years  365426855.0
# 5            Sawera  41.0           MS    8 years    9842568.0
# 6             Zahra  26.0       Master    1 years     514789.0
# 7       Noor Fatima  33.0           MS    5 years    3654897.0
# 8            Kanwal  27.0           BS    2 years    7456695.0
# 9           Shaista  42.0          PHD   12 years    3654789.0
# 10            Saira  36.0       Master    4 years   87453216.0
# 11          Hoorain  28.0       Master  2.7 years          0.0
# 12           Nabila  39.0           BS    7 years    4569873.0
# 13            Nazia  44.0          PHD   11 years   32147895.0
# ...

# %% [markdown]
# ### 43. Isna Function

# %%
pd.isna(t)
# Out:
#     Name of Employee    Age  Qulification  Experience  Phone No  E-mail  \
# 0              False  False         False       False     False   False
# 1              False  False         False       False     False   False
# 2              False  False         False       False     False   False
# 3              False  False         False       False     False   False
# 4              False  False         False       False     False   False
# 5              False  False         False       False     False   False
# 6              False  False         False       False     False   False
# 7              False  False         False       False     False   False
# 8              False  False         False       False     False   False
# 9              False  False         False       False     False   False
# 10             False  False         False       False     False   False
# 11             False  False         False       False     False   False
# ...

# %% [markdown]
# ### 44. Mean Function

# %%
t.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 t.mean()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %% [markdown]
# ### 45. Median function

# %%
t.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 t.median()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11706, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11698 @doc(make_doc("median", ndim=2))
#   11699 def median(
#   11700     self,
#    (...)
#   11704     **kwargs,
#   11705 ):
# > 11706     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707     if isinstance(result, Series):
#   11708         result = result.__finalize__(self, method="median")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
# ...

# %% [markdown]
# ### 46. Mode Function

# %%
t.mode()
# Out:
#    Name of Employee   Age Qulification Experience   Phone No         E-mail  \
# 0              Amna  36.0           BS    0 years  3654897.0  lsk@gmail.com
# 1            Aneeqa   NaN          NaN    1 years        NaN            NaN
# 2             Asifa   NaN          NaN    2 years        NaN            NaN
# 3            Ayesha   NaN          NaN    5 years        NaN            NaN
# 4             Hania   NaN          NaN    6 years        NaN            NaN
# 5             Hibba   NaN          NaN        NaN        NaN            NaN
# 6           Hoorain   NaN          NaN        NaN        NaN            NaN
# 7              Isma   NaN          NaN        NaN        NaN            NaN
# 8            Kainat   NaN          NaN        NaN        NaN            NaN
# 9            Kanwal   NaN          NaN        NaN        NaN            NaN
# 10            Komal   NaN          NaN        NaN        NaN            NaN
# ...

# %% [markdown]
# ### 47. str.lower Function

# %%
t.lower("Name of Employee")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7184\2556352533.py in ?()
# ----> 1 t.lower("Name of Employee")
#
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lower'
