# %% [markdown]
# # Rimsha Saleem
# shrimsha110@gmail.com

# %% [markdown]
# ### importing

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### install excel extention

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ###Data analysis  (retrive data from excel file)

# %%
r = pd.read_excel("Book1.xlsx")         
print("Dataframe")
r
# Out:
# Dataframe
#      English     urdu       math  islamiyat      stat  accounting
# 0   0.807387  0.291431  0.487125   0.555318  0.666047    0.810174
# 1   0.189752  0.959996  0.142821   0.508298  0.083987    0.891542
# 2   0.592088  0.624925  0.524996   0.297211  0.246351    0.187949
# 3   0.098052  0.174829  0.242849   0.781645  0.899884    0.564784
# 4   0.241646  0.702921  0.229525   0.298838  0.246423    0.064312
# 5   0.871239  0.718625  0.496721   0.110215  0.501179    0.271890
# 6   0.906907  0.757190  0.127029   0.025609  0.735139    0.252611
# 7   0.845044  0.718549  0.699068   0.211456  0.850327    0.489750
# 8   0.979610  0.826486  0.342087   0.847393  0.097071    0.834294
# 9   0.074129  0.754650  0.398487   0.748290  0.128002    0.038324
# 10  0.500577  0.097043  0.594589   0.323282  0.748681    0.805660
# 11  0.296134  0.410501  0.301268   0.791403  0.567289    0.696296
# 12  0.521514  0.284706  0.268445   0.121655  0.458121    0.840538
# ...

# %% [markdown]
# #### specfic column based on their integer indice

# %%
r["math"].iloc[2]
# Out:
# np.float64(0.52499574064658)

# %% [markdown]
# #### one dimensional data

# %%
r = pd.Series([1, 3, 5, np.nan, 5, 6])
r
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### sort in ascending order

# %%
sorted_r = r.sort_values()
print(sorted_r)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    5.0
# 5    6.0
# 3    NaN
# dtype: float64

# %% [markdown]
# #### descripted statistice

# %%
r.describe()
# Out:
# count    5.0
# mean     4.0
# std      2.0
# min      1.0
# 25%      3.0
# 50%      5.0
# 75%      5.0
# max      6.0
# dtype: float64

# %% [markdown]
# #### return the first row obj on position

# %%
r. head()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# dtype: float64

# %% [markdown]
# #### specfied num of last row

# %%
r. tail()
# Out:
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### primaly used to array

# %%
r. to_numpy()
# Out:
# array([ 1.,  3.,  5., nan,  5.,  6.])

# %% [markdown]
# #### return the datatype

# %%
r. dtypes
# Out:
# dtype('float64')

# %% [markdown]
# #### transpose index and column

# %%
r. T
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### for rows

# %%
r. index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# #### check the dataframe contains specfied values

# %%
r = pd.Series([1, 3, 5, np.nan, 5, 6,])
result = r.isin([3,5])
print(result)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
r[0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 r[0:3]
#
# NameError: name 'r' is not defined

# %%
import matplotlib . pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib . pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.close ("all")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.close ("all")
#
# NameError: name 'plt' is not defined
