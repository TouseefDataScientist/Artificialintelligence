# %% [markdown]
# # Rimsha Saleem
# shrimsha110@gmail.com

# %% [markdown]
# ### importing

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### install excel extention

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dit\appdata\local\programs\python\python312\lib\site-packages (3.1.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: et-xmlfile in c:\users\dit\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# ###Data analysis  (retrive data from excel file)

# %%
r = pd.read_excel("Book1.xlsx")         
print("Dataframe")
r
# Out:
# Dataframe
#   Unnamed: 0  Islamiyat   English      Urdu      Math      Stat  pakstudy
# 0     1 hour   0.015021  0.597957  0.393486  0.041745  0.152037  0.557229
# 1     2 hour   0.804788  0.189076  0.962615  0.816262  0.477432  0.084729
# 2     3 hour   0.643693  0.734196  0.299738  0.093527  0.772283  0.058246
# 3     4 hour   0.209171  0.718367  0.495380  0.816083  0.942286  0.295342
# 4     5 hour   0.975376  0.593259  0.974276  0.960929  0.017125  0.538454
# 5     6 hour   0.858752  0.554169  0.799520  0.943395  0.867872  0.912334
# 6     7 hour   0.165278  0.114283  0.529515  0.629199  0.183185  0.957302
# 7     8 hour   0.164629  0.666324  0.314646  0.132304  0.841783  0.650054
# 8     9 hour   0.756329  0.280145  0.662411  0.231109  0.519359  0.015335
# 9    10 hour   0.216455  0.921214  0.068994  0.384327  0.567193  0.154987

# %% [markdown]
# #### specfic column based on their integer indice

# %%
r["Math"].iloc[2]
# Out:
# np.float64(0.093526735301795)

# %% [markdown]
# #### one dimensional data

# %%
r = pd.Series([1, 3, 5, np.nan, 5, 6])
r
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### sort in ascending order

# %%
sorted_r = r.sort_values()
print(sorted_r)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    5.0
# 5    6.0
# 3    NaN
# dtype: float64

# %% [markdown]
# #### descripted statistice

# %%
r.describe()
# Out:
# count    5.0
# mean     4.0
# std      2.0
# min      1.0
# 25%      3.0
# 50%      5.0
# 75%      5.0
# max      6.0
# dtype: float64

# %% [markdown]
# #### return the first row obj on position

# %%
r. head()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# dtype: float64

# %% [markdown]
# #### specfied num of last row

# %%
r. tail()
# Out:
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### primaly used to array

# %%
r. to_numpy()
# Out:
# array([ 1.,  3.,  5., nan,  5.,  6.])

# %% [markdown]
# #### return the datatype

# %%
r. dtypes
# Out:
# dtype('float64')

# %% [markdown]
# #### transpose index and column  (rows ko col or col ko rows)

# %%
r. T
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### for rows

# %%
r. index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# #### check the dataframe contains specfied values

# %%
r = pd.Series([1, 3, 5, np.nan, 5, 6,])
result = r.isin([3,5])
print(result)
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# #### slicing

# %%
r[0:3]
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# dtype: float64

# %% [markdown]
# #### mean

# %%
r.mean()
# Out:
# np.float64(4.0)

# %% [markdown]
# #### median

# %%
r.median()
# Out:
# np.float64(5.0)

# %% [markdown]
# #### drop values

# %%
r.drop([2])
# Out:
# 0    1.0
# 1    3.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### info  dataframe k structure or dtype btane k ley

# %%
r.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6 entries, 0 to 5
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      float64
# dtypes: float64(1)
# memory usage: 180.0 bytes

# %% [markdown]
# #### missing value ko fill krvane k ley

# %%
r.fillna(value=2)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    2.0
# 4    5.0
# 5    6.0
# dtype: float64

# %% [markdown]
# #### check specfied values

# %%
pd.isna(r)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
r = pd.Series([100, 255, 300, 120])
r
# Out:
# 0    100
# 1    255
# 2    300
# 3    120
# dtype: int64

# %% [markdown]
# #### col ko acess krne k ley

# %%
r.sort_values(axis=0)
# Out:
# 0    100
# 3    120
# 1    255
# 2    300
# dtype: int64

# %%
r
# Out:
# 0    100
# 1    255
# 2    300
# 3    120
# dtype: int64

# %% [markdown]
# #### single value ko select k ley

# %%
r.iat[5, 2]
# Out:
# np.float64(0.5541690827629885)

# %% [markdown]
# #### sizeing

# %%
Series = pd.Series([1, 2, 3, 4])
print(Series.size)
# Out:
# 4

# %%
r.dropna()
# Out:
#   Unnamed: 0  Islamiyat   English      Urdu      Math      Stat  pakstudy
# 0     1 hour   0.015021  0.597957  0.393486  0.041745  0.152037  0.557229
# 1     2 hour   0.804788  0.189076  0.962615  0.816262  0.477432  0.084729
# 2     3 hour   0.643693  0.734196  0.299738  0.093527  0.772283  0.058246
# 3     4 hour   0.209171  0.718367  0.495380  0.816083  0.942286  0.295342
# 4     5 hour   0.975376  0.593259  0.974276  0.960929  0.017125  0.538454
# 5     6 hour   0.858752  0.554169  0.799520  0.943395  0.867872  0.912334
# 6     7 hour   0.165278  0.114283  0.529515  0.629199  0.183185  0.957302
# 7     8 hour   0.164629  0.666324  0.314646  0.132304  0.841783  0.650054
# 8     9 hour   0.756329  0.280145  0.662411  0.231109  0.519359  0.015335
# 9    10 hour   0.216455  0.921214  0.068994  0.384327  0.567193  0.154987

# %%
r.isna()
# Out:
#    Unnamed: 0  Islamiyat  English   Urdu   Math   Stat  pakstudy
# 0       False      False    False  False  False  False     False
# 1       False      False    False  False  False  False     False
# 2       False      False    False  False  False  False     False
# 3       False      False    False  False  False  False     False
# 4       False      False    False  False  False  False     False
# 5       False      False    False  False  False  False     False
# 6       False      False    False  False  False  False     False
# 7       False      False    False  False  False  False     False
# 8       False      False    False  False  False  False     False
# 9       False      False    False  False  False  False     False

# %%
r.fillna
# Out:
# <bound method NDFrame.fillna of   Unnamed: 0  Islamiyat   English      Urdu      Math      Stat  pakstudy
# 0     1 hour   0.015021  0.597957  0.393486  0.041745  0.152037  0.557229
# 1     2 hour   0.804788  0.189076  0.962615  0.816262  0.477432  0.084729
# 2     3 hour   0.643693  0.734196  0.299738  0.093527  0.772283  0.058246
# 3     4 hour   0.209171  0.718367  0.495380  0.816083  0.942286  0.295342
# 4     5 hour   0.975376  0.593259  0.974276  0.960929  0.017125  0.538454
# 5     6 hour   0.858752  0.554169  0.799520  0.943395  0.867872  0.912334
# 6     7 hour   0.165278  0.114283  0.529515  0.629199  0.183185  0.957302
# 7     8 hour   0.164629  0.666324  0.314646  0.132304  0.841783  0.650054
# 8     9 hour   0.756329  0.280145  0.662411  0.231109  0.519359  0.015335
# 9    10 hour   0.216455  0.921214  0.068994  0.384327  0.567193  0.154987>

# %%
r
# Out:
#   Unnamed: 0  Islamiyat   English      Urdu      Math      Stat  pakstudy
# 0     1 hour   0.015021  0.597957  0.393486  0.041745  0.152037  0.557229
# 1     2 hour   0.804788  0.189076  0.962615  0.816262  0.477432  0.084729
# 2     3 hour   0.643693  0.734196  0.299738  0.093527  0.772283  0.058246
# 3     4 hour   0.209171  0.718367  0.495380  0.816083  0.942286  0.295342
# 4     5 hour   0.975376  0.593259  0.974276  0.960929  0.017125  0.538454
# 5     6 hour   0.858752  0.554169  0.799520  0.943395  0.867872  0.912334
# 6     7 hour   0.165278  0.114283  0.529515  0.629199  0.183185  0.957302
# 7     8 hour   0.164629  0.666324  0.314646  0.132304  0.841783  0.650054
# 8     9 hour   0.756329  0.280145  0.662411  0.231109  0.519359  0.015335
# 9    10 hour   0.216455  0.921214  0.068994  0.384327  0.567193  0.154987
