# %% [markdown]
# ## Install Excel Library

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Open Data File

# %%
a=pd.read_excel("dataset.xlsx")
print("Data Frame:")
a
# Out:
# Data Frame:
#      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Datatype Function

# %%
a.dtypes
# Out:
# Serial no.          int64
# English           float64
# Urdu              float64
# Math              float64
# Science           float64
# Biology           float64
# Statistics        float64
# Programming       float64
# Islamiat          float64
# PakStudy          float64
# Computer          float64
# OOP               float64
# Data Algorithm    float64
# Fundamentals      float64
# dtype: object

# %% [markdown]
# ## Head Function

# %%
a.head()
# Out:
#    Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0           1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1           2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2           3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3           4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4           5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
#
#    Programming  Islamiat  PakStudy  Computer       OOP  Data Algorithm  \
# 0     0.183378  0.545893  0.585795  0.456090  0.689044        0.371018
# 1     0.823154  0.902089  0.979670  0.659039  0.001722        0.740114
# 2     0.159803  0.477694  0.951683  0.749578  0.820221        0.861288
# 3     0.151172  0.080282  0.746319  0.677960  0.185786        0.653406
# 4     0.762926  0.796482  0.343875  0.685543  0.978629        0.159814
#
#    Fundamentals
# 0      0.119230
# 1      0.243773
# 2      0.852572
# ...

# %% [markdown]
# ## Tail Function

# %%
a.tail()
# Out:
#      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
#      Programming  Islamiat  PakStudy  Computer       OOP  Data Algorithm  \
# 213     0.654087  0.034165  0.753198  0.798389  0.422011        0.907144
# 214     0.103401  0.626385  0.402068  0.936157  0.091506        0.554602
# 215     0.089507  0.423952  0.276390  0.387153  0.284311        0.336620
# 216     0.173145  0.673573  0.665649  0.147848  0.035839        0.928172
# 217     0.669525  0.112870  0.393287  0.135613  0.686447        0.478867
#
#      Fundamentals
# 213      0.223075
# 214      0.166109
# ...

# %% [markdown]
# ## Index Function

# %%
a.index
# Out:
# RangeIndex(start=0, stop=218, step=1)

# %% [markdown]
# ## Column Function

# %%
a.columns
# Out:
# Index(['Serial no.', 'English', 'Urdu', 'Math', 'Science', 'Biology',
#        'Statistics', 'Programming', 'Islamiat', 'PakStudy', 'Computer', 'OOP',
#        'Data Algorithm', 'Fundamentals'],
#       dtype='object')

# %% [markdown]
# ## Describe Function

# %%
a.describe
# Out:
# <bound method NDFrame.describe of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Transform Function

# %%
a.T
# Out:
#                      0         1         2         3         4         5    \
# Serial no.      1.000000  2.000000  3.000000  4.000000  5.000000  6.000000
# English         0.268543  0.207745  0.360543  0.178889  0.899584  0.817771
# Urdu            0.470901  0.670918  0.469599  0.427752  0.164451  0.492276
# Math            0.433209  0.303532  0.575028  0.740511  0.047839  0.298242
# Science         0.218869  0.874474  0.649501  0.586176  0.018186  0.545961
# Biology         0.481915  0.629637  0.352566  0.913347  0.696315  0.036595
# Statistics      0.977359  0.209917  0.713967  0.226688  0.439455  0.882190
# Programming     0.183378  0.823154  0.159803  0.151172  0.762926  0.552357
# Islamiat        0.545893  0.902089  0.477694  0.080282  0.796482  0.234178
# PakStudy        0.585795  0.979670  0.951683  0.746319  0.343875  0.535758
# Computer        0.456090  0.659039  0.749578  0.677960  0.685543  0.572783
# ...

# %% [markdown]
# ## Slicing Function

# %%
a[4:8]
# Out:
#    Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 4           5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# 5           6  0.817771  0.492276  0.298242  0.545961  0.036595    0.882190
# 6           7  0.965189  0.337833  0.424813  0.705275  0.959198    0.277034
# 7           8  0.681101  0.398950  0.981473  0.161372  0.832140    0.943539
#
#    Programming  Islamiat  PakStudy  Computer       OOP  Data Algorithm  \
# 4     0.762926  0.796482  0.343875  0.685543  0.978629        0.159814
# 5     0.552357  0.234178  0.535758  0.572783  0.307374        0.850813
# 6     0.810382  0.663540  0.431480  0.749945  0.065043        0.145361
# 7     0.064658  0.010879  0.366595  0.628832  0.377840        0.597878
#
#    Fundamentals
# 4      0.347900
# 5      0.522878
# 6      0.056979
# 7      0.735926

# %% [markdown]
# ## Mean Function

# %%
a.mean
# Out:
# <bound method DataFrame.mean of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Median Function

# %%
a.median
# Out:
# <bound method DataFrame.median of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Mode Function

# %%
a.mode
# Out:
# <bound method DataFrame.mode of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Information Function

# %%
a.info
# Out:
# <bound method DataFrame.info of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Sorting

# %%
a.sort_values(by="Biology")
# Out:
#      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 78           79  0.800010  0.754855  0.502419  0.000087  0.003578    0.213197
# 118         119  0.729350  0.001859  0.559300  0.824136  0.004731    0.432828
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 35           36  0.680792  0.683179  0.758249  0.837754  0.030752    0.572674
# 5             6  0.817771  0.492276  0.298242  0.545961  0.036595    0.882190
# ..          ...       ...       ...       ...       ...       ...         ...
# 117         118  0.517543  0.651587  0.507292  0.996342  0.975939    0.637975
# 96           97  0.859114  0.271911  0.122719  0.570709  0.978605    0.035706
# 97           98  0.973671  0.343248  0.341727  0.912808  0.978728    0.378643
# 176         177  0.805338  0.449186  0.328077  0.364663  0.982228    0.894612
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
#
# ...

# %%
a.sort_index(axis=1, ascending=True)
# Out:
#       Biology  Computer  Data Algorithm   English  Fundamentals  Islamiat  \
# 0    0.481915  0.456090        0.371018  0.268543      0.119230  0.545893
# 1    0.629637  0.659039        0.740114  0.207745      0.243773  0.902089
# 2    0.352566  0.749578        0.861288  0.360543      0.852572  0.477694
# 3    0.913347  0.677960        0.653406  0.178889      0.337946  0.080282
# 4    0.696315  0.685543        0.159814  0.899584      0.347900  0.796482
# ..        ...       ...             ...       ...           ...       ...
# 213  0.020748  0.798389        0.907144  0.479997      0.223075  0.034165
# 214  0.994707  0.936157        0.554602  0.145270      0.166109  0.626385
# 215  0.316508  0.387153        0.336620  0.372925      0.860444  0.423952
# 216  0.047904  0.147848        0.928172  0.763313      0.952713  0.673573
# 217  0.231519  0.135613        0.478867  0.866604      0.547420  0.112870
#
#          Math       OOP  PakStudy  Programming   Science  Serial no.  \
# ...

# %% [markdown]
# ## Tab Function
# Does not run

# %%
a.<TAB>
# Out:
#   Cell In[21], line 1
#     a.<TAB>
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Attribute Function

# %%
a.English
# Out:
# 0      0.268543
# 1      0.207745
# 2      0.360543
# 3      0.178889
# 4      0.899584
#          ...
# 213    0.479997
# 214    0.145270
# 215    0.372925
# 216    0.763313
# 217    0.866604
# Name: English, Length: 218, dtype: float64

# %% [markdown]
# ## Boolean Function

# %%
 a.bool
# Out:
# <bound method NDFrame.bool of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Absolute Function

# %%
a.abs
# Out:
# <bound method NDFrame.abs of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Boxplot Function

# %%
a.boxplot
# Out:
# <bound method boxplot_frame of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Add Function

# %%
a.add
# Out:
# <bound method DataFrame.add of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
#
# ...

# %% [markdown]
# ## Column attribute Function

# %%
a.Islamiat
# Out:
# 0      0.545893
# 1      0.902089
# 2      0.477694
# 3      0.080282
# 4      0.796482
#          ...
# 213    0.034165
# 214    0.626385
# 215    0.423952
# 216    0.673573
# 217    0.112870
# Name: Islamiat, Length: 218, dtype: float64

# %% [markdown]
# ## Add Prefix Function

# %%
a.add_prefix
# Out:
# <bound method NDFrame.add_prefix of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
# ...

# %% [markdown]
# ## Clip Function

# %%
a.clip(4)
# Out:
#      Serial no.  English  Urdu  Math  Science  Biology  Statistics  \
# 0             4      4.0   4.0   4.0      4.0      4.0         4.0
# 1             4      4.0   4.0   4.0      4.0      4.0         4.0
# 2             4      4.0   4.0   4.0      4.0      4.0         4.0
# 3             4      4.0   4.0   4.0      4.0      4.0         4.0
# 4             5      4.0   4.0   4.0      4.0      4.0         4.0
# ..          ...      ...   ...   ...      ...      ...         ...
# 213         214      4.0   4.0   4.0      4.0      4.0         4.0
# 214         215      4.0   4.0   4.0      4.0      4.0         4.0
# 215         216      4.0   4.0   4.0      4.0      4.0         4.0
# 216         217      4.0   4.0   4.0      4.0      4.0         4.0
# 217         218      4.0   4.0   4.0      4.0      4.0         4.0
#
#      Programming  Islamiat  PakStudy  Computer  OOP  Data Algorithm  \
# 0            4.0       4.0       4.0       4.0  4.0             4.0
# ...

# %% [markdown]
# ## Add Suffix Function

# %%
a.add_suffix
# Out:
# <bound method NDFrame.add_suffix of      Serial no.   English      Urdu      Math   Science   Biology  Statistics  \
# 0             1  0.268543  0.470901  0.433209  0.218869  0.481915    0.977359
# 1             2  0.207745  0.670918  0.303532  0.874474  0.629637    0.209917
# 2             3  0.360543  0.469599  0.575028  0.649501  0.352566    0.713967
# 3             4  0.178889  0.427752  0.740511  0.586176  0.913347    0.226688
# 4             5  0.899584  0.164451  0.047839  0.018186  0.696315    0.439455
# ..          ...       ...       ...       ...       ...       ...         ...
# 213         214  0.479997  0.413211  0.263311  0.216626  0.020748    0.702772
# 214         215  0.145270  0.171051  0.304884  0.344013  0.994707    0.470786
# 215         216  0.372925  0.103228  0.581807  0.079013  0.316508    0.668507
# 216         217  0.763313  0.581477  0.712117  0.603937  0.047904    0.013637
# 217         218  0.866604  0.990823  0.410600  0.127100  0.231519    0.044248
# ...
