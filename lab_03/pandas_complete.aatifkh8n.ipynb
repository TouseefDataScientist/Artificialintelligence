# %% [markdown]
# # Complete Pandas by Atif Jamil
# In this notebook, we used Pandas library on BANK dataset. This is a practice code.

# %%
# %pip install numpy
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importing all the dependencies / libs

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading the dataset

# %%
df = pd.read_csv('./datasets/BANK.csv', delimiter=';')

df
# Out:
#      age           job  marital  education default  balance housing loan  \
# 0     58    management  married   tertiary      no     2143     yes   no
# 1     44    technician   single  secondary      no       29     yes   no
# 2     33  entrepreneur  married  secondary      no        2     yes  yes
# 3     47   blue-collar  married    unknown      no     1506     yes   no
# 4     33       unknown   single    unknown      no        1      no   no
# ..   ...           ...      ...        ...     ...      ...     ...  ...
# 244   49    management  married   tertiary      no     3237     yes   no
# 245   42    management  married    unknown      no      275      no   no
# 246   22   blue-collar   single  secondary      no        0     yes   no
# 247   40    management  married   tertiary      no      207     yes   no
# 248   39   blue-collar  married  secondary      no      483     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %% [markdown]
# Information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        249 non-null    int64
#  1   job        249 non-null    object
#  2   marital    249 non-null    object
#  3   education  249 non-null    object
#  4   default    249 non-null    object
#  5   balance    249 non-null    int64
#  6   housing    249 non-null    object
#  7   loan       249 non-null    object
#  8   contact    249 non-null    object
#  9   day        249 non-null    int64
#  10  month      249 non-null    object
#  11  duration   249 non-null    int64
#  12  campaign   249 non-null    int64
#  13  pdays      249 non-null    int64
#  14  previous   249 non-null    int64
#  15  poutcome   249 non-null    object
#  16  y          249 non-null    object
# dtypes: int64(7), object(10)
# memory usage: 33.2+ KB

# %% [markdown]
# Describing the dataset

# %%
df.describe()
# Out:
#               age       balance    day     duration    campaign  pdays  \
# count  249.000000    249.000000  249.0   249.000000  249.000000  249.0
# mean    44.979920    514.694779    5.0   296.369478    1.257028   -1.0
# std      9.792793   1330.950201    0.0   294.284055    0.544586    0.0
# min     22.000000   -674.000000    5.0    13.000000    1.000000   -1.0
# 25%     37.000000     18.000000    5.0   138.000000    1.000000   -1.0
# 50%     45.000000    151.000000    5.0   212.000000    1.000000   -1.0
# 75%     54.000000    424.000000    5.0   346.000000    1.000000   -1.0
# max     61.000000  12223.000000    5.0  2033.000000    5.000000   -1.0
#
#        previous
# count     249.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %% [markdown]
# Showing the data types of all of the features / columns

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# Showing the top 5 indexes / rows

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %% [markdown]
# Showing the bottom 5 indexes / rows

# %%
df.tail()
# Out:
#      age          job  marital  education default  balance housing loan  \
# 244   49   management  married   tertiary      no     3237     yes   no
# 245   42   management  married    unknown      no      275      no   no
# 246   22  blue-collar   single  secondary      no        0     yes   no
# 247   40   management  married   tertiary      no      207     yes   no
# 248   39  blue-collar  married  secondary      no      483     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 244  unknown    5   may       232         3     -1         0  unknown  no
# 245  unknown    5   may       408         2     -1         0  unknown  no
# 246  unknown    5   may       179         2     -1         0  unknown  no
# 247  unknown    5   may        39         1     -1         0  unknown  no
# 248  unknown    5   may       282         1     -1         0  unknown  no

# %% [markdown]
# Arranging the dataset indexex by balance in acsending order

# %%
df.sort_values(by="balance")
# Out:
#      age            job  marital  education default  balance housing loan  \
# 100   44    blue-collar  married  secondary      no     -674     yes   no
# 210   38    blue-collar  married  secondary      no     -390     yes   no
# 25    44         admin.  married  secondary      no     -372     yes   no
# 46    58  self-employed  married   tertiary      no     -364     yes   no
# 28    46     management   single  secondary      no     -246     yes   no
# ..   ...            ...      ...        ...     ...      ...     ...  ...
# 205   50       services  married  secondary      no     5699     yes   no
# 70    57    blue-collar  married  secondary      no     5935     yes  yes
# 65    51     management  married   tertiary      no     6530     yes   no
# 34    51     management  married   tertiary      no    10635     yes   no
# 69    35    blue-collar   single  secondary      no    12223     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %% [markdown]
# Arranging the dataset indexex by balance in decending order

# %%
df.sort_values(by="balance", ascending=False)
# Out:
#      age            job  marital  education default  balance housing loan  \
# 69    35    blue-collar   single  secondary      no    12223     yes  yes
# 34    51     management  married   tertiary      no    10635     yes   no
# 65    51     management  married   tertiary      no     6530     yes   no
# 70    57    blue-collar  married  secondary      no     5935     yes  yes
# 205   50       services  married  secondary      no     5699     yes   no
# ..   ...            ...      ...        ...     ...      ...     ...  ...
# 28    46     management   single  secondary      no     -246     yes   no
# 46    58  self-employed  married   tertiary      no     -364     yes   no
# 25    44         admin.  married  secondary      no     -372     yes   no
# 210   38    blue-collar  married  secondary      no     -390     yes   no
# 100   44    blue-collar  married  secondary      no     -674     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %% [markdown]
# Showing **'age'** column values

# %%
df['age']
# Out:
# 0      58
# 1      44
# 2      33
# 3      47
# 4      33
#        ..
# 244    49
# 245    42
# 246    22
# 247    40
# 248    39
# Name: age, Length: 249, dtype: int64

# %% [markdown]
# Calculating the mean of **'age'** columns / feature

# %%
df['age'].mean()
# Out:
# np.float64(44.97991967871486)

# %% [markdown]
# Accessing the first value of **'age'** column / feature

# %%
# loc() can get a single value or a series
df['age'].loc[0]
# Out:
# np.int64(58)

# %%
# at() can only get a single value
df['age'].at[0]
# Out:
# np.int64(58)

# %% [markdown]
# Filtering the record to get only the inedexes with age of 20 years or more

# %%
df[df['age'] >= 20]
# Out:
#      age           job  marital  education default  balance housing loan  \
# 0     58    management  married   tertiary      no     2143     yes   no
# 1     44    technician   single  secondary      no       29     yes   no
# 2     33  entrepreneur  married  secondary      no        2     yes  yes
# 3     47   blue-collar  married    unknown      no     1506     yes   no
# 4     33       unknown   single    unknown      no        1      no   no
# ..   ...           ...      ...        ...     ...      ...     ...  ...
# 244   49    management  married   tertiary      no     3237     yes   no
# 245   42    management  married    unknown      no      275      no   no
# 246   22   blue-collar   single  secondary      no        0     yes   no
# 247   40    management  married   tertiary      no      207     yes   no
# 248   39   blue-collar  married  secondary      no      483     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df.value_counts()
# Out:
# age  job          marital   education  default  balance  housing  loan  contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 22   blue-collar  single    secondary  no        0       yes      no    unknown  5    may    179       2         -1     0         unknown   no    1
# 23   blue-collar  married   secondary  no        94      yes      no    unknown  5    may    193       1         -1     0         unknown   no    1
# 24   technician   single    secondary  no       -103     yes      yes   unknown  5    may    145       1         -1     0         unknown   no    1
# 25   blue-collar  married   secondary  no       -7       yes      no    unknown  5    may    365       1         -1     0         unknown   no    1
#      services     married   secondary  no        50      yes      no    unknown  5    may    342       1         -1     0         unknown   no    1
# ...
