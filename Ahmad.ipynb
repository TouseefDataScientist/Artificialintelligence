# %%
### Pandas Practice
# import pandas library

# %%
# %pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a = pd.read_excel("business.xlsx")
a
# Out:
#     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
#      Established Year  Revenue ($)  Employees
# ...

# %% [markdown]
# # Displays first five rows of dataset

# %%
a.head()
# Out:
#   Business Name Owner Name Location  Phone Number                 Email  \
# 0    Business_1    Owner_1   City_2    3000000001  business_1@email.com
# 1    Business_2    Owner_2   City_3    3000000002  business_2@email.com
# 2    Business_3    Owner_3   City_4    3000000003  business_3@email.com
# 3    Business_4    Owner_4   City_5    3000000004  business_4@email.com
# 4    Business_5    Owner_5   City_6    3000000005  business_5@email.com
#
#    Established Year  Revenue ($)  Employees
# 0              2001        51000         11
# 1              2002        52000         12
# 2              2003        53000         13
# 3              2004        54000         14
# 4              2005        55000         15

# %% [markdown]
# ## Displays last five rows of dataset

# %%
a.tail()
# Out:
#     Business Name Owner Name Location  Phone Number                   Email  \
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
#      Established Year  Revenue ($)  Employees
# 195              2016       246000         11
# 196              2017       247000         12
# 197              2018       248000         13
# 198              2019       249000         14
# 199              2000       250000         15

# %% [markdown]
# ## index and Columns

# %%
a.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
a.columns
# Out:
# Index(['Business Name', 'Owner Name', 'Location', 'Phone Number', 'Email',
#        'Established Year', 'Revenue ($)', 'Employees'],
#       dtype='object')

# %% [markdown]
# ## describe() shows a quick statistic summary of your data:

# %%
a.describe
# Out:
# <bound method NDFrame.describe of     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
# ...

# %% [markdown]
# ## Transpose

# %%
a.T
# Out:
#                                    0                     1    \
# Business Name               Business_1            Business_2
# Owner Name                     Owner_1               Owner_2
# Location                        City_2                City_3
# Phone Number                3000000001            3000000002
# Email             business_1@email.com  business_2@email.com
# Established Year                  2001                  2002
# Revenue ($)                      51000                 52000
# Employees                           11                    12
#
#                                    2                     3    \
# Business Name               Business_3            Business_4
# Owner Name                     Owner_3               Owner_4
# Location                        City_4                City_5
# Phone Number                3000000003            3000000004
# Email             business_3@email.com  business_4@email.com
# ...

# %%
a.sort_values(by="Email")
# Out:
#     Business Name Owner Name Location  Phone Number                   Email  \
# 99   Business_100  Owner_100   City_1    3000000100  business_100@email.com
# 100  Business_101  Owner_101   City_2    3000000101  business_101@email.com
# 101  Business_102  Owner_102   City_3    3000000102  business_102@email.com
# 102  Business_103  Owner_103   City_4    3000000103  business_103@email.com
# 103  Business_104  Owner_104   City_5    3000000104  business_104@email.com
# ..            ...        ...      ...           ...                     ...
# 95    Business_96   Owner_96   City_7    3000000096   business_96@email.com
# 96    Business_97   Owner_97   City_8    3000000097   business_97@email.com
# 97    Business_98   Owner_98   City_9    3000000098   business_98@email.com
# 98    Business_99   Owner_99  City_10    3000000099   business_99@email.com
# 8      Business_9    Owner_9  City_10    3000000009    business_9@email.com
#
#      Established Year  Revenue ($)  Employees
# ...

# %%
a["Employees"]
# Out:
# 0      11
# 1      12
# 2      13
# 3      14
# 4      15
#        ..
# 195    11
# 196    12
# 197    13
# 198    14
# 199    15
# Name: Employees, Length: 200, dtype: int64

# %%
a[10:20]
# Out:
#    Business Name Owner Name Location  Phone Number                  Email  \
# 10   Business_11   Owner_11   City_2    3000000011  business_11@email.com
# 11   Business_12   Owner_12   City_3    3000000012  business_12@email.com
# 12   Business_13   Owner_13   City_4    3000000013  business_13@email.com
# 13   Business_14   Owner_14   City_5    3000000014  business_14@email.com
# 14   Business_15   Owner_15   City_6    3000000015  business_15@email.com
# 15   Business_16   Owner_16   City_7    3000000016  business_16@email.com
# 16   Business_17   Owner_17   City_8    3000000017  business_17@email.com
# 17   Business_18   Owner_18   City_9    3000000018  business_18@email.com
# 18   Business_19   Owner_19  City_10    3000000019  business_19@email.com
# 19   Business_20   Owner_20   City_1    3000000020  business_20@email.com
#
#     Established Year  Revenue ($)  Employees
# 10              2011        61000         21
# 11              2012        62000         22
# ...

# %%
a.loc[50]
# Out:
# Business Name                 Business_51
# Owner Name                       Owner_51
# Location                           City_2
# Phone Number                   3000000051
# Email               business_51@email.com
# Established Year                     2011
# Revenue ($)                        101000
# Employees                              16
# Name: 50, dtype: object

# %%
a.loc[0:10,["Employees", "Location"]]
# Out:
#     Employees Location
# 0          11   City_2
# 1          12   City_3
# 2          13   City_4
# 3          14   City_5
# 4          15   City_6
# 5          16   City_7
# 6          17   City_8
# 7          18   City_9
# 8          19  City_10
# 9          20   City_1
# 10         21   City_2

# %%
a.iloc[1]
# Out:
# Business Name                 Business_2
# Owner Name                       Owner_2
# Location                          City_3
# Phone Number                  3000000002
# Email               business_2@email.com
# Established Year                    2002
# Revenue ($)                        52000
# Employees                             12
# Name: 1, dtype: object

# %%
a.dropna(how="any")
# Out:
#     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
#      Established Year  Revenue ($)  Employees
# ...

# %%
a.fillna(value=0000)
# Out:
#     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
#      Established Year  Revenue ($)  Employees
# ...

# %%
a['Revenue ($)'].mean()
# Out:
# np.float64(150500.0)

# %%
a.value_counts("Revenue ($)")
# Out:
# Revenue ($)
# 51000     1
# 52000     1
# 53000     1
# 54000     1
# 55000     1
#          ..
# 246000    1
# 247000    1
# 248000    1
# 249000    1
# 250000    1
# Name: count, Length: 200, dtype: int64

# %%
a.mean
# Out:
# <bound method DataFrame.mean of     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
# ...

# %%
a.mode
# Out:
# <bound method DataFrame.mode of     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
# ...

# %%
a.mode
# Out:
# <bound method DataFrame.mode of     Business Name Owner Name Location  Phone Number                   Email  \
# 0      Business_1    Owner_1   City_2    3000000001    business_1@email.com
# 1      Business_2    Owner_2   City_3    3000000002    business_2@email.com
# 2      Business_3    Owner_3   City_4    3000000003    business_3@email.com
# 3      Business_4    Owner_4   City_5    3000000004    business_4@email.com
# 4      Business_5    Owner_5   City_6    3000000005    business_5@email.com
# ..            ...        ...      ...           ...                     ...
# 195  Business_196  Owner_196   City_7    3000000196  business_196@email.com
# 196  Business_197  Owner_197   City_8    3000000197  business_197@email.com
# 197  Business_198  Owner_198   City_9    3000000198  business_198@email.com
# 198  Business_199  Owner_199  City_10    3000000199  business_199@email.com
# 199  Business_200  Owner_200   City_1    3000000200  business_200@email.com
#
# ...
